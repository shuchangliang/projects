# %% [markdown]
# <a href="https://colab.research.google.com/github/shuchangliang/projects/blob/master/Missing%20Value%20Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b44712f8-00d2-4b67-9dcc-017de16b360f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b44712f8-00d2-4b67-9dcc-017de16b360f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cust.csv to cust.csv

# %%
customer = pd.read_csv(io.StringIO(uploaded['cust.csv'].decode('utf-8')))
##account = pd.read_csv(io.StringIO(uploaded['acct.csv'].decode('utf-8')))
##tran = pd.read_csv(io.StringIO(uploaded['tran.csv'].decode('utf-8')))

# %%
customer.head(5)
# Out:
#    Unnamed: 0                                                 id      type  \
# 0           0  fe51c153-fbec-4b64-9b00-2530035ef0e1_1bf5af3c-...  Personal
# 1           1  fe51c153-fbec-4b64-9b00-2530035ef0e1_6e740a94-...  Personal
# 2           2  fe51c153-fbec-4b64-9b00-2530035ef0e1_3918fdef-...  Personal
# 3           3  fe51c153-fbec-4b64-9b00-2530035ef0e1_d81a6d15-...  Personal
# 4           4  fe51c153-fbec-4b64-9b00-2530035ef0e1_e21dfbc8-...  Personal
#
#    gender   birthDate workActivity  \
# 0    Male  12/26/1985          NaN
# 1  Female   1/30/1977     fulltime
# 2  Female  11/22/2003          NaN
# 3   Other    5/7/1983     fulltime
# 4    Male   1/29/1983     fulltime
#
#                                   occupationIndustry  totalIncome  \
# 0                                                NaN          0.0
# 1              5221 Depository credit intermediation      40009.2
# 2                                                NaN          0.0
# ...

# %%
# Define a Function to calculate missing values and missing rate by column

def missing_values_table(df):
        #1 Total missing values
        mis_val = df.isnull().sum()
        
        #2 Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        #3 Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        #4 Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        #5 Only keep the columns with missing values
        mis_val_table_only = mis_val_table_ren_columns.loc[mis_val_table_ren_columns['% of Total Values'] > 0]
        
        #6 Return the dataframe with missing information
        return mis_val_table_only

# %%
missing = missing_values_table(customer)
missing
# Out:
#                     Missing Values  % of Total Values
# workActivity                  1445          25.597874
# occupationIndustry             730          12.931798
# habitationStatus               983          17.413640
# schoolAttendance              4063          71.975199
# schools                       5254          93.073516

# %%
# Alternative way to check missing

def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = df.isnull().sum() / len(df) * 100
    mis_val_table=pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table = mis_val_table.rename(columns={0: "Missing Values", 1: "% of Total Values"})
    mis_val_table_only = mis_val_table.loc[mis_val_table['% of Total Values'] > 0]
    return mis_val_table_only

# %%
missing2 = missing_values_table(customer)
missing2
# Out:
#                     Missing Values  % of Total Values
# workActivity                  1445          25.597874
# occupationIndustry             730          12.931798
# habitationStatus               983          17.413640
# schoolAttendance              4063          71.975199
# schools                       5254          93.073516

# %%
## Find columns with missing > 50%
missing_columns = list(missing.loc[missing['% of Total Values']>50].index)
missing_columns
# Out:
# ['schoolAttendance', 'schools']
