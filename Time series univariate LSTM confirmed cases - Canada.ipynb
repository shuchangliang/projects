# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
df_confirmed = pd.read_csv(url)

# %%
df_confirmed
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/17/20  9/18/20  \
# 0          0        0        0        0        0  ...    38872    38883
# 1          0        0        0        0        0  ...    11948    12073
# 2          0        0        0        0        0  ...    49194    49413
# 3          0        0        0        0        0  ...     1483     1564
# 4          0        0        0        0        0  ...     3789     3848
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...    33843    34401
# 262        0        0        0        0        0  ...       10       10
# 263        0        0        0        0        0  ...     2022     2024
# 264        0        0        0        0        0  ...    13928    14022
# 265        0        0        0        0        0  ...     7633     7647
#
#      9/19/20  9/20/20  9/21/20  9/22/20  9/23/20  9/24/20  9/25/20  9/26/20
# 0      38919    39044    39074    39096    39145    39170    39186    39192
# 1      12226    12385    12535    12666    12787    12921    13045    13153
# 2      49623    49826    50023    50214    50400    50579    50754    50914
# 3       1564     1564     1681     1681     1753     1753     1836     1836
# 4       3901     3991     4117     4236     4363     4475     4590     4672
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 261    35003    35686    36151    36580    37083    37591    37963    38253
# 262       10       10       10       10       10       10       10       10
# 263     2026     2026     2028     2028     2029     2029     2029     2030
# 264    14070    14131    14175    14389    14443    14491    14515    14612
# 265     7672     7683     7683     7711     7725     7752     7787     7803
#
# [266 rows x 253 columns]

# %%
country = "Canada"

# %%
df_confirmed1 = df_confirmed[df_confirmed["Country/Region"] == country]

# %%
# structuring time series data
df_confirmed2 = pd.DataFrame(df_confirmed1[df_confirmed1.columns[4:]].sum(),columns=["confirmed"])
df_confirmed2.index = pd.to_datetime(df_confirmed2.index,format='%m/%d/%y')
df_confirmed2.tail()
# Out:
#             confirmed
# 2020-09-22     148855
# 2020-09-23     149939
# 2020-09-24     151087
# 2020-09-25     152717
# 2020-09-26     153770

# %%
# total dead
df_dead = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")

# %%
df_dead
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/17/20  9/18/20  \
# 0          0        0        0        0        0  ...     1436     1437
# 1          0        0        0        0        0  ...      347      353
# 2          0        0        0        0        0  ...     1654     1659
# 3          0        0        0        0        0  ...       53       53
# 4          0        0        0        0        0  ...      144      147
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...      244      250
# 262        0        0        0        0        0  ...        1        1
# 263        0        0        0        0        0  ...      585      585
# 264        0        0        0        0        0  ...      326      329
# 265        0        0        0        0        0  ...      224      224
#
#      9/19/20  9/20/20  9/21/20  9/22/20  9/23/20  9/24/20  9/25/20  9/26/20
# 0       1437     1441     1444     1445     1446     1451     1451     1453
# 1        358      362      364      367      370      370      373      375
# 2       1665     1672     1679     1689     1698     1703     1707     1711
# 3         53       53       53       53       53       53       53       53
# 4        147      152      154      155      159      162      167      171
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 261      253      262      265      269      272      274      278      285
# 262        1        1        1        1        1        1        1        1
# 263      585      586      586      586      586      586      587      587
# 264      330      330      331      331      332      332      332      332
# 265      225      225      225      226      227      227      227      227
#
# [266 rows x 253 columns]

# %%
df_dead1 = df_dead[df_dead["Country/Region"] == country]

# %%
df_dead2 = pd.DataFrame(df_dead1[df_dead1.columns[4:]].sum(),columns=["dead"])
df_dead2.index = pd.to_datetime(df_dead2.index,format='%m/%d/%y')
df_dead2.tail()
# Out:
#             dead
# 2020-09-22  9286
# 2020-09-23  9294
# 2020-09-24  9297
# 2020-09-25  9306
# 2020-09-26  9313

# %%
# recovered
df_recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
df_recovered
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 248            NaN  West Bank and Gaza  31.952200  35.233200        0
# 249            NaN      Western Sahara  24.215500 -12.885800        0
# 250            NaN               Yemen  15.552727  48.516388        0
# 251            NaN              Zambia -13.133897  27.849332        0
# 252            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/17/20  9/18/20  \
# 0          0        0        0        0        0  ...    32505    32576
# 1          0        0        0        0        0  ...     6788     6831
# 2          0        0        0        0        0  ...    34675    34818
# 3          0        0        0        0        0  ...     1054     1164
# 4          0        0        0        0        0  ...     1405     1443
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 248        0        0        0        0        0  ...    23060    23333
# 249        0        0        0        0        0  ...        8        8
# 250        0        0        0        0        0  ...     1221     1221
# 251        0        0        0        0        0  ...    13029    13207
# 252        0        0        0        0        0  ...     5841     5883
#
#      9/19/20  9/20/20  9/21/20  9/22/20  9/23/20  9/24/20  9/25/20  9/26/20
# 0      32576    32576    32576    32576    32610    32619    32619    32635
# 1       6888     6940     6995     7042     7139     7239     7309     7397
# 2      34923    35047    35180    35307    35428    35544    35654    35756
# 3       1164     1164     1199     1199     1203     1203     1263     1263
# 4       1445     1445     1449     1462     1473     1503     1554     1639
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 248    23446    23700    24428    25469    26288    26934    27183    27704
# 249        8        8        8        8        8        8        8        8
# 250     1221     1227     1235     1240     1245     1250     1255     1260
# 251    13365    13365    13629    13629    13629    13643    13643    13727
# 252     5914     5924     5924     5979     6007     6043     6057     6067
#
# [253 rows x 253 columns]

# %%
df_recovered1 = df_recovered[df_recovered["Country/Region"] == country]

# %%
df_recovered1
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 39            NaN         Canada  56.1304 -106.3468        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  9/17/20  9/18/20  9/19/20  \
# 39        0        0        0        0  ...   124984   125654   125984
#
#     9/20/20  9/21/20  9/22/20  9/23/20  9/24/20  9/25/20  9/26/20
# 39   126592   127684   128890   129850   130576   131709   132253
#
# [1 rows x 253 columns]

# %%
df_recovered2 = pd.DataFrame(df_recovered1[df_recovered1.columns[4:]].sum(),columns=["recovered"])
df_recovered2.index = pd.to_datetime(df_recovered2.index,format='%m/%d/%y')
df_recovered2.tail()
# Out:
#             recovered
# 2020-09-22     128890
# 2020-09-23     129850
# 2020-09-24     130576
# 2020-09-25     131709
# 2020-09-26     132253

# %%
#join confirmed with dead
df_conf_dead = df_confirmed2.join(df_dead2,how = "inner")
df_conf_dead
# Out:
#             confirmed  dead
# 2020-01-22          0     0
# 2020-01-23          0     0
# 2020-01-24          0     0
# 2020-01-25          0     0
# 2020-01-26          1     0
# ...               ...   ...
# 2020-09-22     148855  9286
# 2020-09-23     149939  9294
# 2020-09-24     151087  9297
# 2020-09-25     152717  9306
# 2020-09-26     153770  9313
#
# [249 rows x 2 columns]

# %%
# join confirmed+dead with recovered
df_all = df_conf_dead.join(df_recovered2,how = "inner")
df_all
# Out:
#             confirmed  dead  recovered
# 2020-01-22          0     0          0
# 2020-01-23          0     0          0
# 2020-01-24          0     0          0
# 2020-01-25          0     0          0
# 2020-01-26          1     0          0
# ...               ...   ...        ...
# 2020-09-22     148855  9286     128890
# 2020-09-23     149939  9294     129850
# 2020-09-24     151087  9297     130576
# 2020-09-25     152717  9306     131709
# 2020-09-26     153770  9313     132253
#
# [249 rows x 3 columns]

# %%
#plt.figure(figsize=(5,5))
df_all.plot(figsize=(10,5),title="Canada")

# %%
df_confirmed2.plot(title="Canada-Confirmed cases")

# %%
df_new = df_confirmed2[["confirmed"]]
df_new.tail(10)
# Out:
#             confirmed
# 2020-09-17     142879
# 2020-09-18     144053
# 2020-09-19     144607
# 2020-09-20     145750
# 2020-09-21     147583
# 2020-09-22     148855
# 2020-09-23     149939
# 2020-09-24     151087
# 2020-09-25     152717
# 2020-09-26     153770

# %%
#daily data and i want to predict 30 days afterwards
len(df_new)
# Out:
# 249

# %%
x = len(df_new)-30
x
# Out:
# 219

# %%
train=df_new.iloc[:x]
test = df_new.iloc[x:]
train
# Out:
#             confirmed
# 2020-01-22          0
# 2020-01-23          0
# 2020-01-24          0
# 2020-01-25          0
# 2020-01-26          1
# ...               ...
# 2020-08-23     126817
# 2020-08-24     127594
# 2020-08-25     127903
# 2020-08-26     128380
# 2020-08-27     128836
#
# [219 rows x 1 columns]

# %%
#scale or normalize data as the data is too skewed
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(train) #scaling
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)#and divide every point by max value
scaled_test = scaler.transform(test)
print(scaled_train[-30:])
# Out:
# [[0.91090223]
#  [0.91338601]
#  [0.91807414]
#  [0.9199525 ]
#  [0.92185414]
#  [0.92344531]
#  [0.92876991]
#  [0.93167282]
#  [0.9344205 ]
#  [0.9384256 ]
#  [0.94032724]
#  [0.94202707]
#  [0.94735167]
#  [0.94995964]
#  [0.95239685]
#  [0.95609923]
#  [0.95939799]
#  [0.96110559]
#  [0.96249495]
#  [0.96415598]
#  [0.9708777 ]
#  [0.97339253]
#  [0.97507684]
#  [0.98046354]
#  [0.98233413]
#  [0.98432891]
#  [0.99035984]
#  [0.99275824]
#  [0.99646062]
#  [1.        ]]

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
scaled_train.shape
# Out:
# (219, 1)

# %%
# how to decide num of inputs , 
n_input = 30  ## number of steps
n_features = 1 ## number of features you want to predict (for univariate time series n_features=1)
generator = TimeseriesGenerator(scaled_train,scaled_train,length = n_input,batch_size=1)

# %%
len(scaled_train)
# Out:
# 219

# %%
len(generator)
# Out:
# 189

# %%
x,y = generator[50]

# %%
(x.shape,y.shape)
# Out:
# ((1, 30, 1), (1, 1))

# %%
(x,y)
# Out:
# (array([[[0.00090813],
#          [0.00149803],
#          [0.00153684],
#          [0.00195598],
#          [0.00322115],
#          [0.00371014],
#          [0.00509951],
#          [0.00620944],
#          [0.00731938],
#          [0.00991183],
#          [0.01140209],
#          [0.01620665],
#          [0.02165544],
#          [0.02523363],
#          [0.03137322],
#          [0.03634077],
#          [0.04327983],
#          [0.04874414],
#          [0.05742184],
#          [0.06618492],
#          [0.07420286],
#          [0.08758422],
#          [0.09653358],
#          [0.10073271],
#          [0.12229501],
#          [0.12855879],
#          [0.13871899],
#          [0.14856872],
#          [0.16031234],
#          [0.17121767]]]),
#  array([[0.18097426]]))

# %%
# above takes 30 inputs and predicts next point in scaled_train
# smaller batch size leads to better trainig for time series

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation

# %%
model = Sequential()
model.add(LSTM(150,activation="relu",input_shape=(n_input,n_features)))
#model.add(Dropout(0.2))
model.add(Dense(75, activation='relu'))
model.add(Dense(units=1))
#model.add(Activation('softmax'))
#model.add(Dense(1))
model.compile(optimizer="adam",loss="mse")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_1 (Dense)              (None, 75)                11325
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 76
# =================================================================
# Total params: 102,601
# Trainable params: 102,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
validation_set = np.append(scaled_train[55],scaled_test)
validation_set=validation_set.reshape(31,1)
validation_set
# Out:
# array([[0.00371014],
#        [1.00392747],
#        [1.00623273],
#        [1.00816542],
#        [1.01616008],
#        [1.02007203],
#        [1.02410041],
#        [1.02864882],
#        [1.03341457],
#        [1.03628644],
#        [1.03922817],
#        [1.0423717 ],
#        [1.05371946],
#        [1.05665342],
#        [1.06302586],
#        [1.06861436],
#        [1.07240212],
#        [1.07609674],
#        [1.08741346],
#        [1.09363842],
#        [1.10102766],
#        [1.10899904],
#        [1.1181114 ],
#        [1.12241144],
#        [1.13128318],
#        [1.14551057],
#        [1.15538359],
#        [1.16379739],
#        [1.17270794],
#        [1.18535968],
#        [1.19353286]])

# %%
n_input = 30
n_features = 1
validation_gen = TimeseriesGenerator(validation_set,validation_set,length=30,batch_size=1)

# %%
validation_gen[0][0].shape,validation_gen[0][1].shape
# Out:
# ((1, 30, 1), (1, 1))

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=20,restore_best_weights=True)

# %%
model.fit_generator(generator,validation_data=validation_gen,epochs=100,callbacks=[early_stop],steps_per_epoch=10)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.5587 - val_loss: 0.5593
# Epoch 2/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1106 - val_loss: 2.1456
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0484 - val_loss: 0.3241
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0774 - val_loss: 0.3439
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0788 - val_loss: 0.1675
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0254 - val_loss: 0.0042
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0227
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 2.6390e-05
# Epoch 9/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 10/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 3.0591e-05
# Epoch 11/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 5.7308e-04 - val_loss: 7.0788e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 2.1216e-04 - val_loss: 1.0692e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0206e-04 - val_loss: 0.0029
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.5399e-04 - val_loss: 0.0022
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 7.0473e-05 - val_loss: 3.2136e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 3.1238e-05 - val_loss: 0.0018
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 2.0620e-04 - val_loss: 0.0027
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1700e-04 - val_loss: 4.4263e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.6586e-05 - val_loss: 0.0018
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.0158e-04 - val_loss: 0.0012
# Epoch 22/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.0075e-04 - val_loss: 9.3147e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.7169e-05 - val_loss: 0.0015
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.1941e-04 - val_loss: 8.9609e-04
# Epoch 25/100
# 10/10 [==============================] - 0s 10ms/step - loss: 3.2718e-05 - val_loss: 0.0019
# Epoch 26/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.2986e-04 - val_loss: 0.0020
# Epoch 27/100
# 10/10 [==============================] - 0s 10ms/step - loss: 6.5493e-05 - val_loss: 8.0429e-04
# Epoch 28/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.7386e-04 - val_loss: 0.0018

# %%
pd.DataFrame(model.history.history).plot(title="loss vs epochs curve")

# %%
model.history.history.keys()
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
myloss = model.history.history["val_loss"]
plt.title("validation loss vs epochs")
plt.plot(range(len(myloss)),myloss)

# %% [markdown]
# ## Forecast

# %%
# holding predictions
test_prediction = []

#last n points from training set
first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape(1,n_input,n_features)

# %%
current_batch.shape
# Out:
# (1, 30, 1)

# %%
# how far in future we can predict, 15 days
for i in range(len(test)+15):
    current_pred = model.predict(current_batch)[0]
    test_prediction.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_prediction
# Out:
# [array([1.0308084], dtype=float32),
#  array([1.0380975], dtype=float32),
#  array([1.0457286], dtype=float32),
#  array([1.0536506], dtype=float32),
#  array([1.0618318], dtype=float32),
#  array([1.0702621], dtype=float32),
#  array([1.078925], dtype=float32),
#  array([1.0878085], dtype=float32),
#  array([1.0968993], dtype=float32),
#  array([1.1061797], dtype=float32),
#  array([1.1156365], dtype=float32),
#  array([1.1252613], dtype=float32),
#  array([1.1350634], dtype=float32),
#  array([1.1450356], dtype=float32),
#  array([1.1551882], dtype=float32),
#  array([1.1655216], dtype=float32),
#  array([1.1760287], dtype=float32),
#  array([1.1867077], dtype=float32),
#  array([1.1975787], dtype=float32),
#  array([1.2086147], dtype=float32),
#  array([1.2198386], dtype=float32),
#  array([1.2312866], dtype=float32),
#  array([1.2429638], dtype=float32),
#  array([1.2548838], dtype=float32),
#  array([1.2670634], dtype=float32),
#  array([1.279511], dtype=float32),
#  array([1.2922385], dtype=float32),
#  array([1.3052657], dtype=float32),
#  array([1.318608], dtype=float32),
#  array([1.3322774], dtype=float32),
#  array([1.3462994], dtype=float32),
#  array([1.3607234], dtype=float32),
#  array([1.3755467], dtype=float32),
#  array([1.3907956], dtype=float32),
#  array([1.4064963], dtype=float32),
#  array([1.4226767], dtype=float32),
#  array([1.4393663], dtype=float32),
#  array([1.4565982], dtype=float32),
#  array([1.4744093], dtype=float32),
#  array([1.4928402], dtype=float32),
#  array([1.5119339], dtype=float32),
#  array([1.5317369], dtype=float32),
#  array([1.5522993], dtype=float32),
#  array([1.5736729], dtype=float32),
#  array([1.5959198], dtype=float32)]

# %%
# inverse scaled data
true_prediction = scaler.inverse_transform(test_prediction)
true_prediction[:,0]
# Out:
# array([132805.2373085 , 133744.32961321, 134727.48530531, 135748.13096905,
#        136802.1658988 , 137888.28462648, 139004.38304472, 140148.89459181,
#        141320.11448002, 142515.76965904, 143734.1399827 , 144974.16571808,
#        146237.02946568, 147521.80971861, 148829.82730341, 150161.14365387,
#        151514.83726311, 152890.6777544 , 154291.24534702, 155713.08439016,
#        157159.1283474 , 158634.04618692, 160138.48296356, 161674.20489883,
#        163243.37753391, 164847.07596016, 166486.83602238, 168165.20722294,
#        169884.18616009, 171645.29332018, 173451.83076954, 175310.15690565,
#        177219.93384266, 179184.54043913, 181207.35555363, 183291.97306299,
#        185442.20186234, 187662.28088331, 189957.00196171, 192331.55625296,
#        194791.51887369, 197342.84890175, 199992.0276022 , 202745.72054148,
#        205611.92947102])

# %%
time_series_array = test.index
for k in range(0,15):
    time_series_array = time_series_array.append(time_series_array[-1:] + pd.DateOffset(1))
time_series_array
# Out:
# DatetimeIndex(['2020-08-28', '2020-08-29', '2020-08-30', '2020-08-31',
#                '2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-05', '2020-09-06', '2020-09-07', '2020-09-08',
#                '2020-09-09', '2020-09-10', '2020-09-11', '2020-09-12',
#                '2020-09-13', '2020-09-14', '2020-09-15', '2020-09-16',
#                '2020-09-17', '2020-09-18', '2020-09-19', '2020-09-20',
#                '2020-09-21', '2020-09-22', '2020-09-23', '2020-09-24',
#                '2020-09-25', '2020-09-26', '2020-09-27', '2020-09-28',
#                '2020-09-29', '2020-09-30', '2020-10-01', '2020-10-02',
#                '2020-10-03', '2020-10-04', '2020-10-05', '2020-10-06',
#                '2020-10-07', '2020-10-08', '2020-10-09', '2020-10-10',
#                '2020-10-11'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_forecast = pd.DataFrame(columns=["confirmed","confirmed_predicted"],index=time_series_array)
df_forecast
# Out:
#            confirmed confirmed_predicted
# 2020-08-28       NaN                 NaN
# 2020-08-29       NaN                 NaN
# 2020-08-30       NaN                 NaN
# 2020-08-31       NaN                 NaN
# 2020-09-01       NaN                 NaN
# 2020-09-02       NaN                 NaN
# 2020-09-03       NaN                 NaN
# 2020-09-04       NaN                 NaN
# 2020-09-05       NaN                 NaN
# 2020-09-06       NaN                 NaN
# 2020-09-07       NaN                 NaN
# 2020-09-08       NaN                 NaN
# 2020-09-09       NaN                 NaN
# 2020-09-10       NaN                 NaN
# 2020-09-11       NaN                 NaN
# 2020-09-12       NaN                 NaN
# 2020-09-13       NaN                 NaN
# 2020-09-14       NaN                 NaN
# 2020-09-15       NaN                 NaN
# 2020-09-16       NaN                 NaN
# 2020-09-17       NaN                 NaN
# 2020-09-18       NaN                 NaN
# 2020-09-19       NaN                 NaN
# 2020-09-20       NaN                 NaN
# 2020-09-21       NaN                 NaN
# 2020-09-22       NaN                 NaN
# 2020-09-23       NaN                 NaN
# 2020-09-24       NaN                 NaN
# 2020-09-25       NaN                 NaN
# 2020-09-26       NaN                 NaN
# 2020-09-27       NaN                 NaN
# 2020-09-28       NaN                 NaN
# 2020-09-29       NaN                 NaN
# 2020-09-30       NaN                 NaN
# 2020-10-01       NaN                 NaN
# 2020-10-02       NaN                 NaN
# 2020-10-03       NaN                 NaN
# 2020-10-04       NaN                 NaN
# 2020-10-05       NaN                 NaN
# 2020-10-06       NaN                 NaN
# 2020-10-07       NaN                 NaN
# 2020-10-08       NaN                 NaN
# 2020-10-09       NaN                 NaN
# 2020-10-10       NaN                 NaN
# 2020-10-11       NaN                 NaN

# %%
df_forecast.loc[:,"confirmed_predicted"] = true_prediction[:,0]
df_forecast.loc[:,"confirmed"] = test["confirmed"]

# %%
df_forecast
# Out:
#             confirmed  confirmed_predicted
# 2020-08-28   129342.0        132805.237309
# 2020-08-29   129639.0        133744.329613
# 2020-08-30   129888.0        134727.485305
# 2020-08-31   130918.0        135748.130969
# 2020-09-01   131422.0        136802.165899
# 2020-09-02   131941.0        137888.284626
# 2020-09-03   132527.0        139004.383045
# 2020-09-04   133141.0        140148.894592
# 2020-09-05   133511.0        141320.114480
# 2020-09-06   133890.0        142515.769659
# 2020-09-07   134295.0        143734.139983
# 2020-09-08   135757.0        144974.165718
# 2020-09-09   136135.0        146237.029466
# 2020-09-10   136956.0        147521.809719
# 2020-09-11   137676.0        148829.827303
# 2020-09-12   138164.0        150161.143654
# 2020-09-13   138640.0        151514.837263
# 2020-09-14   140098.0        152890.677754
# 2020-09-15   140900.0        154291.245347
# 2020-09-16   141852.0        155713.084390
# 2020-09-17   142879.0        157159.128347
# 2020-09-18   144053.0        158634.046187
# 2020-09-19   144607.0        160138.482964
# 2020-09-20   145750.0        161674.204899
# 2020-09-21   147583.0        163243.377534
# 2020-09-22   148855.0        164847.075960
# 2020-09-23   149939.0        166486.836022
# 2020-09-24   151087.0        168165.207223
# 2020-09-25   152717.0        169884.186160
# 2020-09-26   153770.0        171645.293320
# 2020-09-27        NaN        173451.830770
# 2020-09-28        NaN        175310.156906
# 2020-09-29        NaN        177219.933843
# 2020-09-30        NaN        179184.540439
# 2020-10-01        NaN        181207.355554
# 2020-10-02        NaN        183291.973063
# 2020-10-03        NaN        185442.201862
# 2020-10-04        NaN        187662.280883
# 2020-10-05        NaN        189957.001962
# 2020-10-06        NaN        192331.556253
# 2020-10-07        NaN        194791.518874
# 2020-10-08        NaN        197342.848902
# 2020-10-09        NaN        199992.027602
# 2020-10-10        NaN        202745.720541
# 2020-10-11        NaN        205611.929471

# %%
df_forecast.plot(title="Canada Predictions for next 15 days")

# %%
MAPE = np.mean(np.abs(np.array(df_forecast["confirmed"][:15]) - np.array(df_forecast["confirmed_predicted"][:15]))/np.array(df_forecast["confirmed"][:15]))
print("MAPE is " + str(MAPE*100) + " %")
# Out:
# MAPE is 5.423902408637011 %

# %%
df_forecast["Model Accuracy"] = round((1-MAPE),2)
df_forecast
# Out:
#             confirmed  confirmed_predicted  Model Accuracy
# 2020-08-28   129342.0        132805.237309            0.95
# 2020-08-29   129639.0        133744.329613            0.95
# 2020-08-30   129888.0        134727.485305            0.95
# 2020-08-31   130918.0        135748.130969            0.95
# 2020-09-01   131422.0        136802.165899            0.95
# 2020-09-02   131941.0        137888.284626            0.95
# 2020-09-03   132527.0        139004.383045            0.95
# 2020-09-04   133141.0        140148.894592            0.95
# 2020-09-05   133511.0        141320.114480            0.95
# 2020-09-06   133890.0        142515.769659            0.95
# 2020-09-07   134295.0        143734.139983            0.95
# 2020-09-08   135757.0        144974.165718            0.95
# 2020-09-09   136135.0        146237.029466            0.95
# 2020-09-10   136956.0        147521.809719            0.95
# 2020-09-11   137676.0        148829.827303            0.95
# 2020-09-12   138164.0        150161.143654            0.95
# 2020-09-13   138640.0        151514.837263            0.95
# 2020-09-14   140098.0        152890.677754            0.95
# 2020-09-15   140900.0        154291.245347            0.95
# 2020-09-16   141852.0        155713.084390            0.95
# 2020-09-17   142879.0        157159.128347            0.95
# 2020-09-18   144053.0        158634.046187            0.95
# 2020-09-19   144607.0        160138.482964            0.95
# 2020-09-20   145750.0        161674.204899            0.95
# 2020-09-21   147583.0        163243.377534            0.95
# 2020-09-22   148855.0        164847.075960            0.95
# 2020-09-23   149939.0        166486.836022            0.95
# 2020-09-24   151087.0        168165.207223            0.95
# 2020-09-25   152717.0        169884.186160            0.95
# 2020-09-26   153770.0        171645.293320            0.95
# 2020-09-27        NaN        173451.830770            0.95
# 2020-09-28        NaN        175310.156906            0.95
# 2020-09-29        NaN        177219.933843            0.95
# 2020-09-30        NaN        179184.540439            0.95
# 2020-10-01        NaN        181207.355554            0.95
# 2020-10-02        NaN        183291.973063            0.95
# 2020-10-03        NaN        185442.201862            0.95
# 2020-10-04        NaN        187662.280883            0.95
# 2020-10-05        NaN        189957.001962            0.95
# 2020-10-06        NaN        192331.556253            0.95
# 2020-10-07        NaN        194791.518874            0.95
# 2020-10-08        NaN        197342.848902            0.95
# 2020-10-09        NaN        199992.027602            0.95
# 2020-10-10        NaN        202745.720541            0.95
# 2020-10-11        NaN        205611.929471            0.95

# %%
from datetime import datetime
df_forecast["Country"] = country
df_forecast["Execution date"] = str(datetime.now()).split()[0]
df_forecast
# Out:
#             confirmed  confirmed_predicted  Model Accuracy Country  \
# 2020-08-28   129342.0        132805.237309            0.95  Canada
# 2020-08-29   129639.0        133744.329613            0.95  Canada
# 2020-08-30   129888.0        134727.485305            0.95  Canada
# 2020-08-31   130918.0        135748.130969            0.95  Canada
# 2020-09-01   131422.0        136802.165899            0.95  Canada
# 2020-09-02   131941.0        137888.284626            0.95  Canada
# 2020-09-03   132527.0        139004.383045            0.95  Canada
# 2020-09-04   133141.0        140148.894592            0.95  Canada
# 2020-09-05   133511.0        141320.114480            0.95  Canada
# 2020-09-06   133890.0        142515.769659            0.95  Canada
# 2020-09-07   134295.0        143734.139983            0.95  Canada
# 2020-09-08   135757.0        144974.165718            0.95  Canada
# 2020-09-09   136135.0        146237.029466            0.95  Canada
# 2020-09-10   136956.0        147521.809719            0.95  Canada
# 2020-09-11   137676.0        148829.827303            0.95  Canada
# 2020-09-12   138164.0        150161.143654            0.95  Canada
# 2020-09-13   138640.0        151514.837263            0.95  Canada
# 2020-09-14   140098.0        152890.677754            0.95  Canada
# 2020-09-15   140900.0        154291.245347            0.95  Canada
# 2020-09-16   141852.0        155713.084390            0.95  Canada
# 2020-09-17   142879.0        157159.128347            0.95  Canada
# 2020-09-18   144053.0        158634.046187            0.95  Canada
# 2020-09-19   144607.0        160138.482964            0.95  Canada
# 2020-09-20   145750.0        161674.204899            0.95  Canada
# 2020-09-21   147583.0        163243.377534            0.95  Canada
# 2020-09-22   148855.0        164847.075960            0.95  Canada
# 2020-09-23   149939.0        166486.836022            0.95  Canada
# 2020-09-24   151087.0        168165.207223            0.95  Canada
# 2020-09-25   152717.0        169884.186160            0.95  Canada
# 2020-09-26   153770.0        171645.293320            0.95  Canada
# 2020-09-27        NaN        173451.830770            0.95  Canada
# 2020-09-28        NaN        175310.156906            0.95  Canada
# 2020-09-29        NaN        177219.933843            0.95  Canada
# 2020-09-30        NaN        179184.540439            0.95  Canada
# 2020-10-01        NaN        181207.355554            0.95  Canada
# 2020-10-02        NaN        183291.973063            0.95  Canada
# 2020-10-03        NaN        185442.201862            0.95  Canada
# 2020-10-04        NaN        187662.280883            0.95  Canada
# 2020-10-05        NaN        189957.001962            0.95  Canada
# 2020-10-06        NaN        192331.556253            0.95  Canada
# 2020-10-07        NaN        194791.518874            0.95  Canada
# 2020-10-08        NaN        197342.848902            0.95  Canada
# 2020-10-09        NaN        199992.027602            0.95  Canada
# 2020-10-10        NaN        202745.720541            0.95  Canada
# 2020-10-11        NaN        205611.929471            0.95  Canada
#
#            Execution date
# 2020-08-28     2020-09-27
# 2020-08-29     2020-09-27
# 2020-08-30     2020-09-27
# 2020-08-31     2020-09-27
# 2020-09-01     2020-09-27
# 2020-09-02     2020-09-27
# 2020-09-03     2020-09-27
# 2020-09-04     2020-09-27
# 2020-09-05     2020-09-27
# 2020-09-06     2020-09-27
# 2020-09-07     2020-09-27
# 2020-09-08     2020-09-27
# 2020-09-09     2020-09-27
# 2020-09-10     2020-09-27
# 2020-09-11     2020-09-27
# 2020-09-12     2020-09-27
# 2020-09-13     2020-09-27
# 2020-09-14     2020-09-27
# 2020-09-15     2020-09-27
# 2020-09-16     2020-09-27
# 2020-09-17     2020-09-27
# 2020-09-18     2020-09-27
# 2020-09-19     2020-09-27
# 2020-09-20     2020-09-27
# 2020-09-21     2020-09-27
# 2020-09-22     2020-09-27
# 2020-09-23     2020-09-27
# 2020-09-24     2020-09-27
# 2020-09-25     2020-09-27
# 2020-09-26     2020-09-27
# 2020-09-27     2020-09-27
# 2020-09-28     2020-09-27
# 2020-09-29     2020-09-27
# 2020-09-30     2020-09-27
# 2020-10-01     2020-09-27
# 2020-10-02     2020-09-27
# 2020-10-03     2020-09-27
# 2020-10-04     2020-09-27
# 2020-10-05     2020-09-27
# 2020-10-06     2020-09-27
# 2020-10-07     2020-09-27
# 2020-10-08     2020-09-27
# 2020-10-09     2020-09-27
# 2020-10-10     2020-09-27
# 2020-10-11     2020-09-27
